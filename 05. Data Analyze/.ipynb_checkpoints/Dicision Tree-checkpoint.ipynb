# %%
import numpy as np
import pandas as pd

# 모델 라이브러리 선언
from sklearn import datasets, tree

# 모델 정확도 라이브러리 선언
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score

# %%
featuresData = pd.read_csv('../dataset/feature_regression_example.csv')

# %%
featuresData
# Out:
#            REGIONID PRODUCTGROUP      PRODUCT      ITEM  YEARWEEK  YEAR  WEEK  \
# 0    SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201501  2015     1
# 1    SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201502  2015     2
# 2    SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201503  2015     3
# 3    SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201504  2015     4
# 4    SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201505  2015     5
# 5    SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201506  2015     6
# 6    SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201507  2015     7
# 7    SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201508  2015     8
# 8    SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201509  2015     9
# 9    SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201510  2015    10
# 10   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201511  2015    11
# 11   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201512  2015    12
# 12   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201513  2015    13
# 13   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201514  2015    14
# 14   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201515  2015    15
# 15   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201516  2015    16
# 16   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201517  2015    17
# 17   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201518  2015    18
# 18   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201519  2015    19
# 19   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201520  2015    20
# 20   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201521  2015    21
# 21   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201522  2015    22
# 22   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201523  2015    23
# 23   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201524  2015    24
# 24   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201525  2015    25
# 25   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201526  2015    26
# 26   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201527  2015    27
# 27   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201528  2015    28
# 28   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201529  2015    29
# 29   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201530  2015    30
# ..              ...          ...          ...       ...       ...   ...   ...
# 77   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201625  2016    25
# 78   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201626  2016    26
# 79   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201627  2016    27
# 80   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201628  2016    28
# 81   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201629  2016    29
# 82   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201630  2016    30
# 83   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201631  2016    31
# 84   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201632  2016    32
# 85   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201633  2016    33
# 86   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201634  2016    34
# 87   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201635  2016    35
# 88   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201636  2016    36
# 89   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201637  2016    37
# 90   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201638  2016    38
# 91   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201639  2016    39
# 92   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201640  2016    40
# 93   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201641  2016    41
# 94   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201642  2016    42
# 95   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201643  2016    43
# 96   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201644  2016    44
# 97   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201645  2016    45
# 98   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201646  2016    46
# 99   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201647  2016    47
# 100  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201648  2016    48
# 101  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201649  2016    49
# 102  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201650  2016    50
# 103  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201651  2016    51
# 104  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201652  2016    52
# 105  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201710  2017    10
# 106  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201714  2017    14
#
#       QTY HOLIDAY  HCLUS PROMOTION  PRO_PERCENT
# 0    1225       Y      1         Y     0.209442
# 1     968       N      4         Y     0.209442
# 2    1209       N      4         Y     0.208155
# 3    1810       Y      2         Y     0.208155
# 4    1773       N      4         Y     0.208155
# 5     867       N      4         Y     0.208155
# 6    1187       N      4         Y     0.208155
# 7     970       Y      1         Y     0.208155
# 8     542       N      4         Y     0.208155
# 9     350       N      4         N     0.000000
# 10    988       N      4         Y     0.208155
# 11   1314       N      4         Y     0.208155
# 12    741       N      4         Y     0.208155
# 13    466       N      4         Y     0.208155
# 14    301       N      4         N     0.000000
# 15    375       N      4         N     0.000000
# 16    456       N      4         N     0.000000
# 17    526       N      4         N     0.000000
# 18    641       N      4         N     0.000000
# 19    862       Y      1         Y     0.209442
# 20   1335       Y      1         Y     0.209442
# 21   1801       Y      1         Y     0.209442
# 22   1325       N      4         Y     0.209442
# 23    607       N      4         N     0.000000
# 24    337       Y      1         N     0.000000
# 25   2505       Y      1         Y     0.280258
# 26   4035       Y      1         Y     0.280258
# 27   3535       Y      1         Y     0.280258
# 28   2671       Y      1         Y     0.280258
# 29    436       N      4         N     0.000000
# ..    ...     ...    ...       ...          ...
# 77    968       Y      1         Y     0.308584
# 78   1685       Y      1         Y     0.308584
# 79   1586       Y      1         Y     0.308584
# 80   1616       Y      1         Y     0.308584
# 81   1318       Y      1         Y     0.308584
# 82   2240       N      4         Y     0.280258
# 83   1522       N      4         Y     0.280258
# 84   2100       N      4         Y     0.280258
# 85     43       N      4         N     0.000000
# 86   1700       Y      1         Y     0.308584
# 87   1514       Y      1         Y     0.308584
# 88   1501       Y      1         Y     0.308584
# 89   1491       N      4         Y     0.308584
# 90    806       N      4         Y     0.308584
# 91   2111       N      4         Y     0.280258
# 92   2400       N      4         Y     0.280258
# 93   2010       Y      2         Y     0.280258
# 94   1900       N      4         Y     0.280258
# 95    141       N      4         N     0.000000
# 96   1615       Y      0         Y     0.421888
# 97   1574       Y      0         Y     0.421888
# 98   1800       Y      0         Y     0.421888
# 99   2600       Y      0         Y     0.421888
# 100  2412       Y      0         Y     0.421888
# 101  1955       N      4         Y     0.421888
# 102  1800       N      4         Y     0.352361
# 103  1173       N      4         Y     0.352361
# 104   332       Y      1         Y     0.352361
# 105    14       N      4         N     0.000000
# 106     5       N      4         N     0.000000
#
# [107 rows x 12 columns]

# %%
featuresData2=featuresData[["HOLIDAY","PROMOTION"]]

# %%
def refining(df):
    if df['HOLIDAY']=="Y":
        return 1
    elif df['HOLIDAY']=="N":
        return 0

# %%
def refining2(df):
    if df['PROMOTION']=="Y":
        return 1
    elif df['PROMOTION']=="N":
        return 0

# %%
featuresData2["HOLIDAY"] = featuresData2.apply(refining, axis=1)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
featuresData2["PROMOTION"] = featuresData2.apply(refining2, axis=1)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
featuresData2.columns = ["HO_YN", "PRO_YN"]

# %%
featuresData = pd.merge(featuresData, featuresData2, how='outer', left_index=True, right_index=True)

# %%
featuresData.head()
# Out:
#          REGIONID PRODUCTGROUP      PRODUCT      ITEM  YEARWEEK  YEAR  WEEK  \
# 0  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201501  2015     1
# 1  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201502  2015     2
# 2  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201503  2015     3
# 3  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201504  2015     4
# 4  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201505  2015     5
#
#     QTY HOLIDAY  HCLUS PROMOTION  PRO_PERCENT  HO_YN  PRO_YN
# 0  1225       Y      1         Y     0.209442      1       1
# 1   968       N      4         Y     0.209442      0       1
# 2  1209       N      4         Y     0.208155      0       1
# 3  1810       Y      2         Y     0.208155      1       1
# 4  1773       N      4         Y     0.208155      0       1

# %%
# featuresData["HO_YN"] = np.where(featuresData["HOLIDAY"] == "Y",1,0)
# featuresData["PRO_YN"] = np.where(featuresData["PROMOTION"] == "Y",1,0)

# %%
featuresData.dtypes
# Out:
# REGIONID         object
# PRODUCTGROUP     object
# PRODUCT          object
# ITEM             object
# YEARWEEK          int64
# YEAR              int64
# WEEK              int64
# QTY               int64
# HOLIDAY          object
# HCLUS             int64
# PROMOTION        object
# PRO_PERCENT     float64
# HO_YN             int64
# PRO_YN            int64
# dtype: object

# %%
featuresData = featuresData[(featuresData.YEARWEEK >= 201501) & \
                                (featuresData.YEARWEEK <= 201652)]

# %%
featuresData
# Out:
#            REGIONID PRODUCTGROUP      PRODUCT      ITEM  YEARWEEK  YEAR  WEEK  \
# 0    SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201501  2015     1
# 1    SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201502  2015     2
# 2    SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201503  2015     3
# 3    SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201504  2015     4
# 4    SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201505  2015     5
# 5    SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201506  2015     6
# 6    SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201507  2015     7
# 7    SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201508  2015     8
# 8    SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201509  2015     9
# 9    SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201510  2015    10
# 10   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201511  2015    11
# 11   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201512  2015    12
# 12   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201513  2015    13
# 13   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201514  2015    14
# 14   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201515  2015    15
# 15   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201516  2015    16
# 16   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201517  2015    17
# 17   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201518  2015    18
# 18   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201519  2015    19
# 19   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201520  2015    20
# 20   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201521  2015    21
# 21   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201522  2015    22
# 22   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201523  2015    23
# 23   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201524  2015    24
# 24   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201525  2015    25
# 25   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201526  2015    26
# 26   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201527  2015    27
# 27   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201528  2015    28
# 28   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201529  2015    29
# 29   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201530  2015    30
# ..              ...          ...          ...       ...       ...   ...   ...
# 75   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201623  2016    23
# 76   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201624  2016    24
# 77   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201625  2016    25
# 78   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201626  2016    26
# 79   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201627  2016    27
# 80   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201628  2016    28
# 81   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201629  2016    29
# 82   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201630  2016    30
# 83   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201631  2016    31
# 84   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201632  2016    32
# 85   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201633  2016    33
# 86   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201634  2016    34
# 87   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201635  2016    35
# 88   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201636  2016    36
# 89   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201637  2016    37
# 90   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201638  2016    38
# 91   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201639  2016    39
# 92   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201640  2016    40
# 93   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201641  2016    41
# 94   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201642  2016    42
# 95   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201643  2016    43
# 96   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201644  2016    44
# 97   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201645  2016    45
# 98   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201646  2016    46
# 99   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201647  2016    47
# 100  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201648  2016    48
# 101  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201649  2016    49
# 102  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201650  2016    50
# 103  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201651  2016    51
# 104  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201652  2016    52
#
#       QTY HOLIDAY  HCLUS PROMOTION  PRO_PERCENT  HO_YN  PRO_YN
# 0    1225       Y      1         Y     0.209442      1       1
# 1     968       N      4         Y     0.209442      0       1
# 2    1209       N      4         Y     0.208155      0       1
# 3    1810       Y      2         Y     0.208155      1       1
# 4    1773       N      4         Y     0.208155      0       1
# 5     867       N      4         Y     0.208155      0       1
# 6    1187       N      4         Y     0.208155      0       1
# 7     970       Y      1         Y     0.208155      1       1
# 8     542       N      4         Y     0.208155      0       1
# 9     350       N      4         N     0.000000      0       0
# 10    988       N      4         Y     0.208155      0       1
# 11   1314       N      4         Y     0.208155      0       1
# 12    741       N      4         Y     0.208155      0       1
# 13    466       N      4         Y     0.208155      0       1
# 14    301       N      4         N     0.000000      0       0
# 15    375       N      4         N     0.000000      0       0
# 16    456       N      4         N     0.000000      0       0
# 17    526       N      4         N     0.000000      0       0
# 18    641       N      4         N     0.000000      0       0
# 19    862       Y      1         Y     0.209442      1       1
# 20   1335       Y      1         Y     0.209442      1       1
# 21   1801       Y      1         Y     0.209442      1       1
# 22   1325       N      4         Y     0.209442      0       1
# 23    607       N      4         N     0.000000      0       0
# 24    337       Y      1         N     0.000000      1       0
# 25   2505       Y      1         Y     0.280258      1       1
# 26   4035       Y      1         Y     0.280258      1       1
# 27   3535       Y      1         Y     0.280258      1       1
# 28   2671       Y      1         Y     0.280258      1       1
# 29    436       N      4         N     0.000000      0       0
# ..    ...     ...    ...       ...          ...    ...     ...
# 75    973       N      4         Y     0.280258      0       1
# 76     21       N      4         N     0.000000      0       0
# 77    968       Y      1         Y     0.308584      1       1
# 78   1685       Y      1         Y     0.308584      1       1
# 79   1586       Y      1         Y     0.308584      1       1
# 80   1616       Y      1         Y     0.308584      1       1
# 81   1318       Y      1         Y     0.308584      1       1
# 82   2240       N      4         Y     0.280258      0       1
# 83   1522       N      4         Y     0.280258      0       1
# 84   2100       N      4         Y     0.280258      0       1
# 85     43       N      4         N     0.000000      0       0
# 86   1700       Y      1         Y     0.308584      1       1
# 87   1514       Y      1         Y     0.308584      1       1
# 88   1501       Y      1         Y     0.308584      1       1
# 89   1491       N      4         Y     0.308584      0       1
# 90    806       N      4         Y     0.308584      0       1
# 91   2111       N      4         Y     0.280258      0       1
# 92   2400       N      4         Y     0.280258      0       1
# 93   2010       Y      2         Y     0.280258      1       1
# 94   1900       N      4         Y     0.280258      0       1
# 95    141       N      4         N     0.000000      0       0
# 96   1615       Y      0         Y     0.421888      1       1
# 97   1574       Y      0         Y     0.421888      1       1
# 98   1800       Y      0         Y     0.421888      1       1
# 99   2600       Y      0         Y     0.421888      1       1
# 100  2412       Y      0         Y     0.421888      1       1
# 101  1955       N      4         Y     0.421888      0       1
# 102  1800       N      4         Y     0.352361      0       1
# 103  1173       N      4         Y     0.352361      0       1
# 104   332       Y      1         Y     0.352361      1       1
#
# [105 rows x 14 columns]

# %%
corrDf = featuresData.corr()

# %%
corrDf
# Out:
#              YEARWEEK      YEAR      WEEK       QTY     HCLUS  PRO_PERCENT  \
# YEARWEEK     1.000000  0.956598  0.275593  0.112267 -0.071586     0.404889
# YEAR         0.956598  1.000000 -0.016493  0.028931  0.028593     0.321193
# WEEK         0.275593 -0.016493  1.000000  0.289766 -0.339943     0.329705
# QTY          0.112267  0.028931  0.289766  1.000000 -0.537230     0.700195
# HCLUS       -0.071586  0.028593 -0.339943 -0.537230  1.000000    -0.545619
# PRO_PERCENT  0.404889  0.321193  0.329705  0.700195 -0.545619     1.000000
# HO_YN        0.049867 -0.031106  0.273710  0.505932 -0.974601     0.487062
# PRO_YN       0.205916  0.195931  0.060206  0.612451 -0.374072     0.898554
#
#                 HO_YN    PRO_YN
# YEARWEEK     0.049867  0.205916
# YEAR        -0.031106  0.195931
# WEEK         0.273710  0.060206
# QTY          0.505932  0.612451
# HCLUS       -0.974601 -0.374072
# PRO_PERCENT  0.487062  0.898554
# HO_YN        1.000000  0.365148
# PRO_YN       0.365148  1.000000

# %%
corrResult = corrDf.reset_index()

# %%
featuresStd = 0.5

# %%
# abs => 절대값으로 변환

# %%
features = corrResult[(corrResult.QTY != 1) & (abs(corrResult.QTY)>featuresStd)]["index"].tolist()

# %%
features
# Out:
# ['HCLUS', 'PRO_PERCENT', 'HO_YN', 'PRO_YN']

# %%
label = ['QTY']
label
# Out:
# ['QTY']

# %%
yearweekStd = 201630

# %%
trainingData_features = featuresData[featuresData.YEARWEEK <= yearweekStd][features]
trainingData_label = featuresData[featuresData.YEARWEEK <= yearweekStd][label]
testData_features = featuresData[featuresData.YEARWEEK > yearweekStd][features]
testData_label = featuresData[featuresData.YEARWEEK > yearweekStd]

# %%
type(testData_label)
# Out:
# pandas.core.frame.DataFrame

# %%
model_method = tree.DecisionTreeClassifier()

# %%
model = model_method.fit(trainingData_features, trainingData_label)

# %%
predict = model.predict(testData_features)

# %%
predictData = pd.DataFrame(predict)

# %%
predictData.columns = ["PREDICT"]

# %%
testingData = pd.DataFrame(testData_label)

# %%
testingData = testingData.reset_index(drop=True)

# %%
# merge 사용

# %%
mergedData = pd.merge(testingData, predictData, how='outer', left_index=True, right_index=True)

# %%
mergedData
# Out:
#           REGIONID PRODUCTGROUP      PRODUCT      ITEM  YEARWEEK  YEAR  WEEK  \
# 0   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201631  2016    31
# 1   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201632  2016    32
# 2   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201633  2016    33
# 3   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201634  2016    34
# 4   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201635  2016    35
# 5   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201636  2016    36
# 6   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201637  2016    37
# 7   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201638  2016    38
# 8   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201639  2016    39
# 9   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201640  2016    40
# 10  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201641  2016    41
# 11  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201642  2016    42
# 12  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201643  2016    43
# 13  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201644  2016    44
# 14  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201645  2016    45
# 15  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201646  2016    46
# 16  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201647  2016    47
# 17  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201648  2016    48
# 18  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201649  2016    49
# 19  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201650  2016    50
# 20  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201651  2016    51
# 21  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201652  2016    52
#
#      QTY HOLIDAY  HCLUS PROMOTION  PRO_PERCENT  HO_YN  PRO_YN  PREDICT
# 0   1522       N      4         Y     0.280258      0       1      973
# 1   2100       N      4         Y     0.280258      0       1      973
# 2     43       N      4         N     0.000000      0       0       16
# 3   1700       Y      1         Y     0.308584      1       1      968
# 4   1514       Y      1         Y     0.308584      1       1      968
# 5   1501       Y      1         Y     0.308584      1       1      968
# 6   1491       N      4         Y     0.308584      0       1      973
# 7    806       N      4         Y     0.308584      0       1      973
# 8   2111       N      4         Y     0.280258      0       1      973
# 9   2400       N      4         Y     0.280258      0       1      973
# 10  2010       Y      2         Y     0.280258      1       1     1172
# 11  1900       N      4         Y     0.280258      0       1      973
# 12   141       N      4         N     0.000000      0       0       16
# 13  1615       Y      0         Y     0.421888      1       1     2033
# 14  1574       Y      0         Y     0.421888      1       1     2033
# 15  1800       Y      0         Y     0.421888      1       1     2033
# 16  2600       Y      0         Y     0.421888      1       1     2033
# 17  2412       Y      0         Y     0.421888      1       1     2033
# 18  1955       N      4         Y     0.421888      0       1     2033
# 19  1800       N      4         Y     0.352361      0       1     2033
# 20  1173       N      4         Y     0.352361      0       1     2033
# 21   332       Y      1         Y     0.352361      1       1     2033

# %%
# concat 사용

# %%
mergedData2 = pd.concat([testingData,predictData], axis=1)

# %%
mergedData2
# Out:
#           REGIONID PRODUCTGROUP      PRODUCT      ITEM  YEARWEEK  YEAR  WEEK  \
# 0   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201631  2016    31
# 1   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201632  2016    32
# 2   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201633  2016    33
# 3   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201634  2016    34
# 4   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201635  2016    35
# 5   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201636  2016    36
# 6   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201637  2016    37
# 7   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201638  2016    38
# 8   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201639  2016    39
# 9   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201640  2016    40
# 10  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201641  2016    41
# 11  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201642  2016    42
# 12  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201643  2016    43
# 13  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201644  2016    44
# 14  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201645  2016    45
# 15  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201646  2016    46
# 16  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201647  2016    47
# 17  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201648  2016    48
# 18  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201649  2016    49
# 19  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201650  2016    50
# 20  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201651  2016    51
# 21  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201652  2016    52
#
#      QTY HOLIDAY  HCLUS PROMOTION  PRO_PERCENT  HO_YN  PRO_YN  PREDICT
# 0   1522       N      4         Y     0.280258      0       1      973
# 1   2100       N      4         Y     0.280258      0       1      973
# 2     43       N      4         N     0.000000      0       0       16
# 3   1700       Y      1         Y     0.308584      1       1      968
# 4   1514       Y      1         Y     0.308584      1       1      968
# 5   1501       Y      1         Y     0.308584      1       1      968
# 6   1491       N      4         Y     0.308584      0       1      973
# 7    806       N      4         Y     0.308584      0       1      973
# 8   2111       N      4         Y     0.280258      0       1      973
# 9   2400       N      4         Y     0.280258      0       1      973
# 10  2010       Y      2         Y     0.280258      1       1     1172
# 11  1900       N      4         Y     0.280258      0       1      973
# 12   141       N      4         N     0.000000      0       0       16
# 13  1615       Y      0         Y     0.421888      1       1     2033
# 14  1574       Y      0         Y     0.421888      1       1     2033
# 15  1800       Y      0         Y     0.421888      1       1     2033
# 16  2600       Y      0         Y     0.421888      1       1     2033
# 17  2412       Y      0         Y     0.421888      1       1     2033
# 18  1955       N      4         Y     0.421888      0       1     2033
# 19  1800       N      4         Y     0.352361      0       1     2033
# 20  1173       N      4         Y     0.352361      0       1     2033
# 21   332       Y      1         Y     0.352361      1       1     2033

# %%
mergedData.to_csv('./finalresult.csv', encoding='ms949', index=False)

# %%
finalResult = pd.read_csv('./finalresult.csv')

# %%
finalResult
# Out:
#           REGIONID PRODUCTGROUP      PRODUCT      ITEM  YEARWEEK  YEAR  WEEK  \
# 0   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201631  2016    31
# 1   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201632  2016    32
# 2   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201633  2016    33
# 3   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201634  2016    34
# 4   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201635  2016    35
# 5   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201636  2016    36
# 6   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201637  2016    37
# 7   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201638  2016    38
# 8   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201639  2016    39
# 9   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201640  2016    40
# 10  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201641  2016    41
# 11  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201642  2016    42
# 12  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201643  2016    43
# 13  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201644  2016    44
# 14  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201645  2016    45
# 15  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201646  2016    46
# 16  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201647  2016    47
# 17  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201648  2016    48
# 18  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201649  2016    49
# 19  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201650  2016    50
# 20  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201651  2016    51
# 21  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201652  2016    52
#
#      QTY HOLIDAY  HCLUS PROMOTION  PRO_PERCENT  HO_YN  PRO_YN  PREDICT
# 0   1522       N      4         Y     0.280258      0       1      973
# 1   2100       N      4         Y     0.280258      0       1      973
# 2     43       N      4         N     0.000000      0       0       16
# 3   1700       Y      1         Y     0.308584      1       1      968
# 4   1514       Y      1         Y     0.308584      1       1      968
# 5   1501       Y      1         Y     0.308584      1       1      968
# 6   1491       N      4         Y     0.308584      0       1      973
# 7    806       N      4         Y     0.308584      0       1      973
# 8   2111       N      4         Y     0.280258      0       1      973
# 9   2400       N      4         Y     0.280258      0       1      973
# 10  2010       Y      2         Y     0.280258      1       1     1172
# 11  1900       N      4         Y     0.280258      0       1      973
# 12   141       N      4         N     0.000000      0       0       16
# 13  1615       Y      0         Y     0.421888      1       1     2033
# 14  1574       Y      0         Y     0.421888      1       1     2033
# 15  1800       Y      0         Y     0.421888      1       1     2033
# 16  2600       Y      0         Y     0.421888      1       1     2033
# 17  2412       Y      0         Y     0.421888      1       1     2033
# 18  1955       N      4         Y     0.421888      0       1     2033
# 19  1800       N      4         Y     0.352361      0       1     2033
# 20  1173       N      4         Y     0.352361      0       1     2033
# 21   332       Y      1         Y     0.352361      1       1     2033

# %%
# MAE

# %%
mean_absolute_error(finalResult['QTY'], finalResult['PREDICT'])
# Out:
# 617.3636363636364

# %%
# RMSE(MSE)

# %%
mean_squared_error(finalResult['QTY'], finalResult['PREDICT'])
# Out:
# 567875.9090909091

# %%
# R2

# %%
r2_score(finalResult['QTY'], finalResult['PREDICT'])
# Out:
# -0.2162570590202968
