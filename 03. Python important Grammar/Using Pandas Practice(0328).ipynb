# %%
import pandas as pd

# %%
customerData = pd.read_csv("../dataset/customerdata.csv")

# %%
customerData.head()
# Out:
#    CUSTID  AVERAGEPRICE  EMI  DEVICECOUNT  PRODUCTAGE          CUSTTYPE
# 0  A13566   4273.900000    3          6.4    1.679181  Big-Screen-lover
# 1  A14219   3642.441950    2          4.0    2.682023      Sleeping-dog
# 2  A15312   3653.884565    2          5.0    3.208202      Sleeping-dog
# 3  A16605   3713.211107    2          6.6    0.900000        Early-bird
# 4  B10634   3391.074215    2          4.2    2.453656      Sleeping-dog

# %%
customerData[(customerData.EMI==3)&(customerData.DEVICECOUNT>5)]
# Out:
#      CUSTID  AVERAGEPRICE  EMI  DEVICECOUNT  PRODUCTAGE          CUSTTYPE
# 0    A13566   4273.900000    3          6.4    1.679181  Big-Screen-lover
# 27   F17131   3179.708359    3          6.5    1.100000        Early-bird
# 33   G16437   3787.328898    3          6.7    1.000000        Early-bird
# 36   G18402   3402.199381    3          6.5    1.000000        Early-bird
# 40   H16326   3988.935304    3          6.5    0.900000        Early-bird
# 45   I12899   3018.895637    3          6.4    0.900000        Early-bird
# 51   J10809   3676.135627    3          6.5    0.800000        Early-bird
# 52   J15083   2811.265932    3          6.0    0.900000        Early-bird
# 53   J16445   3041.848186    3          6.4    0.800000        Early-bird
# 60   L13892   3263.515145    3          6.7    1.100000        Early-bird
# 67   N13273   3839.694732    3          6.9    1.100000        Early-bird
# 95   R16364   3592.353540    3          6.2    0.900000        Early-bird
# ...

# %%
customerData.dtypes
# Out:
# CUSTID           object
# AVERAGEPRICE    float64
# EMI               int64
# DEVICECOUNT     float64
# PRODUCTAGE      float64
# CUSTTYPE         object
# dtype: object

# %%
customerData["EMI"]=customerData["EMI"].astype(int)
customerData.dtypes
# Out:
# CUSTID           object
# AVERAGEPRICE    float64
# EMI               int32
# DEVICECOUNT     float64
# PRODUCTAGE      float64
# CUSTTYPE         object
# dtype: object

# %%
kopo_customerData = pd.read_csv("../dataset/kopo_customerdata.csv")

# %%
kopo_customerData.head()
# Out:
#    CUSTOMERCODE STATENAME  ST  GENDER  DOB  GENDER1  EMAIL  FEST_CNT  \
# 0       1503989    State2   2    Male    0        1      1         0
# 1       1190338    State2   2    Male    0        1      0         1
# 2       1424715    State2   2  Female    0        2      0         0
# 3       2483305    State2   2    Male    0        1      0         1
# 4       1178802    State2   2    Male    0        1      0         1
#
#    TOTAL_AMOUNT  AC_AMOUNT  AV_AMOUNT  HA_AMOUNT  EMI_CE_AMOUNT  IS_HIGHEND  \
# 0         30300          0      30300          0              0           0
# 1         46500          0      46500          0              0           0
# 2         22700          0          0      22700              0           0
# 3         31400          0      31400          0              0           0
# 4         44900          0          0      44900              0           0
#
#    CNT_VIST  GAP_VISIT
# 0         1          0
# 1         1          0
# ...

# %%
kopo_customerData = kopo_customerData[(kopo_customerData.GENDER=="Male")&(kopo_customerData.EMAIL>0)]

# %%
kopo_customerData.head(20)
# Out:
#      CUSTOMERCODE STATENAME  ST GENDER  DOB  GENDER1  EMAIL  FEST_CNT  \
# 0         1503989    State2   2   Male    0        1      1         0
# 16        1154228    State2   2   Male    0        1      1         0
# 81         393246    State2   2   Male    0        1      1         1
# 206       2532568    State2   2   Male    1        1      1         0
# 216        487928    State2   2   Male    0        1      1         0
# 226       2452240    State2   2   Male    1        1      1         1
# 299       1295854    State2   2   Male    1        1      1         2
# 308        554757    State2   2   Male    0        1      1         0
# 330        761018    State2   2   Male    1        1      1         0
# 367       2191152    State2   2   Male    0        1      1         1
# 375        867914    State2   2   Male    0        1      1         0
# 415       1804886    State2   2   Male    0        1      1         1
# ...

# %%
targetGender = "Male"

# %%
targetGender = targetGender.upper()

# %%
targetEmail = 0

# %%
kopo_customerData[(kopo_customerData.GENDER.str.upper()==targetGender)&(kopo_customerData.EMAIL>targetEmail)]
# Out:
#      CUSTOMERCODE STATENAME  ST GENDER  DOB  GENDER1  EMAIL  FEST_CNT  \
# 0         1503989    State2   2   Male    0        1      1         0
# 16        1154228    State2   2   Male    0        1      1         0
# 81         393246    State2   2   Male    0        1      1         1
# 206       2532568    State2   2   Male    1        1      1         0
# 216        487928    State2   2   Male    0        1      1         0
# 226       2452240    State2   2   Male    1        1      1         1
# 299       1295854    State2   2   Male    1        1      1         2
# 308        554757    State2   2   Male    0        1      1         0
# 330        761018    State2   2   Male    1        1      1         0
# 367       2191152    State2   2   Male    0        1      1         1
# 375        867914    State2   2   Male    0        1      1         0
# 415       1804886    State2   2   Male    0        1      1         1
# ...

# %%
kopo_product_volume = pd.read_csv("../dataset/kopo_product_volume.csv")

# %%
kopo_product_volume.head(10)
# Out:
#   REGIONID PRODUCTGROUP  YEARWEEK  VOLUME
# 0      A01       ST0001    201415  810144
# 1      A01       ST0002    201415  128999
# 2      A01       ST0001    201418  671464
# 3      A01       ST0002    201418  134467
# 4      A01       ST0001    201413  470040
# 5      A01       ST0002    201413  140297
# 6      A01       ST0001    201411  524787
# 7      A01       ST0002    201411  145509
# 8      A01       ST0001    201416  764927
# 9      A01       ST0002    201416  140313

# %%
kopo_product_volume_select=kopo_product_volume[(kopo_product_volume.PRODUCTGROUP=="ST0002")&(kopo_product_volume.VOLUME>300000)]
kopo_product_volume_select
# Out:
#     REGIONID PRODUCTGROUP  YEARWEEK   VOLUME
# 80       A01       ST0002    201452   422468
# 86       A01       ST0002    201451   356271
# 90       A01       ST0002    201449   669711
# 94       A01       ST0002    201447   378339
# 102      A01       ST0002    201448  1400339
# 196      A01       ST0002    201552   422468
# 208      A01       ST0002    201551   356271
# 212      A01       ST0002    201549   669711
# 216      A01       ST0002    201547   378339
# 224      A01       ST0002    201548  1400339
