# %%
import pandas as pd

# %%
customerData = pd.read_csv("../../01.Python_Git/dataset/kopo_customerdata.csv")

# %% [markdown]
# # 데이터를 원하는 칼럼으로 추출

# %%
customerData[["CUSTOMERCODE","ST","STATENAME","GENDER","TOTAL_AMOUNT"]].head()
# Out:
#    CUSTOMERCODE  ST STATENAME  GENDER  TOTAL_AMOUNT
# 0       1503989   2    State2    Male         30300
# 1       1190338   2    State2    Male         46500
# 2       1424715   2    State2  Female         22700
# 3       2483305   2    State2    Male         31400
# 4       1178802   2    State2    Male         44900

# %% [markdown]
# # loc[n:n2,:] = 해당 데이터의 n행부터 n2행까지 출력

# %%
dfc1 = customerData.loc[0:2,:]
dfc1
# Out:
#    CUSTOMERCODE STATENAME  ST  GENDER  DOB  GENDER1  EMAIL  FEST_CNT  \
# 0       1503989    State2   2    Male    0        1      1         0
# 1       1190338    State2   2    Male    0        1      0         1
# 2       1424715    State2   2  Female    0        2      0         0
#
#    TOTAL_AMOUNT  AC_AMOUNT  AV_AMOUNT  HA_AMOUNT  EMI_CE_AMOUNT  IS_HIGHEND  \
# 0         30300          0      30300          0              0           0
# 1         46500          0      46500          0              0           0
# 2         22700          0          0      22700              0           0
#
#    CNT_VIST  GAP_VISIT
# 0         1          0
# 1         1          0
# 2         1          0

# %% [markdown]
# # iloc[n:n2,[n3,n4]] = 해당 데이터의 행은 n부터 n2행까지 열은 n3부터 n4까지

# %%
dfc2 = customerData.iloc[0:5,[1,3]]
dfc2
# Out:
#   STATENAME  GENDER
# 0    State2    Male
# 1    State2    Male
# 2    State2  Female
# 3    State2    Male
# 4    State2    Male

# %%
customerDataColumns = customerData.columns
customerDataColumns
# Out:
# Index(['CUSTOMERCODE', 'STATENAME', 'ST', 'GENDER', 'DOB', 'GENDER1', 'EMAIL',
#        'FEST_CNT', 'TOTAL_AMOUNT', 'AC_AMOUNT', 'AV_AMOUNT', 'HA_AMOUNT',
#        'EMI_CE_AMOUNT', 'IS_HIGHEND', 'CNT_VIST', 'GAP_VISIT'],
#       dtype='object')

# %% [markdown]
# # 'get_loc' = 해당 칼럼의 인덱스번호를 가지게 함

# %%
csCodeNolNo = customerData.columns.get_loc("CUSTOMERCODE")
stColNo = customerData.columns.get_loc("ST")

# %%
csCodeNolNo
# Out:
# 0

# %%
stColNo
# Out:
# 2

# %%
customerData2 = pd.read_csv("../../01.Python_Git/dataset/customerdata.csv")

# %%
customerData2
# Out:
#      CUSTID  AVERAGEPRICE  EMI  DEVICECOUNT  PRODUCTAGE          CUSTTYPE
# 0    A13566   4273.900000    3          6.4    1.679181  Big-Screen-lover
# 1    A14219   3642.441950    2          4.0    2.682023      Sleeping-dog
# 2    A15312   3653.884565    2          5.0    3.208202      Sleeping-dog
# 3    A16605   3713.211107    2          6.6    0.900000        Early-bird
# 4    B10634   3391.074215    2          4.2    2.453656      Sleeping-dog
# 5    B16849   3755.263391    2          4.7    2.786665      Sleeping-dog
# 6    B18816   3213.911446    2          6.4    0.900000        Early-bird
# 7    C10639   3516.500000    2          5.2    2.564830  Big-Screen-lover
# 8    C12717   3732.900000    2          5.7    2.069995  Big-Screen-lover
# 9    C15050   4020.173425    2          4.9    3.013440      Sleeping-dog
# 10   C18306   4005.005142    2          4.7    3.113618      Sleeping-dog
# 11   C18622   3246.000000    1          5.0    1.891624  Big-Screen-lover
# ...

# %% [markdown]
# # 데이터에 열을 추가하고 추가하는 열의 내용을 기존 열에서 추출하여 가져오기

# %%
import numpy as np
customerData2["PRODUCTAGE_NEW"] = np.where(customerData2["PRODUCTAGE"]<1, 1,\
                                           np.where(customerData2["PRODUCTAGE"]<2,2, \
                                                    np.where(customerData2["PRODUCTAGE"]<3,3,\
                                                             5)))

# %%
customerData2.head()
# Out:
#    CUSTID  AVERAGEPRICE  EMI  DEVICECOUNT  PRODUCTAGE          CUSTTYPE  \
# 0  A13566   4273.900000    3          6.4    1.679181  Big-Screen-lover
# 1  A14219   3642.441950    2          4.0    2.682023      Sleeping-dog
# 2  A15312   3653.884565    2          5.0    3.208202      Sleeping-dog
# 3  A16605   3713.211107    2          6.6    0.900000        Early-bird
# 4  B10634   3391.074215    2          4.2    2.453656      Sleeping-dog
#
#    PRODUCTAGE_NEW
# 0               2
# 1               3
# 2               5
# 3               1
# 4               3

# %% [markdown]
# # 함수를 이용하여 추가 내용 정의

# %%
def refining(df):
    if df['PRODUCTAGE'] < 1:
        return 1
    elif df['PRODUCTAGE'] < 2:
        return 2
    else:
        return 5

# %%
customerData2["PRODUCTAGE_NEW2"] = customerData2.apply(refining, axis = 1)

# %%
customerData2.head(30)
# Out:
#     CUSTID  AVERAGEPRICE  EMI  DEVICECOUNT  PRODUCTAGE          CUSTTYPE  \
# 0   A13566   4273.900000    3          6.4    1.679181  Big-Screen-lover
# 1   A14219   3642.441950    2          4.0    2.682023      Sleeping-dog
# 2   A15312   3653.884565    2          5.0    3.208202      Sleeping-dog
# 3   A16605   3713.211107    2          6.6    0.900000        Early-bird
# 4   B10634   3391.074215    2          4.2    2.453656      Sleeping-dog
# 5   B16849   3755.263391    2          4.7    2.786665      Sleeping-dog
# 6   B18816   3213.911446    2          6.4    0.900000        Early-bird
# 7   C10639   3516.500000    2          5.2    2.564830  Big-Screen-lover
# 8   C12717   3732.900000    2          5.7    2.069995  Big-Screen-lover
# 9   C15050   4020.173425    2          4.9    3.013440      Sleeping-dog
# 10  C18306   4005.005142    2          4.7    3.113618      Sleeping-dog
# 11  C18622   3246.000000    1          5.0    1.891624  Big-Screen-lover
# ...

# %% [markdown]
# # sort를 사용하여 내용 정렬하기

# %%
sortkey = ["CUSTID"]

# %%
customerData2.sort_values(sortkey, inplace = True)

# %%
customerData2
# Out:
#      CUSTID  AVERAGEPRICE  EMI  DEVICECOUNT  PRODUCTAGE          CUSTTYPE  \
# 0    A13566   4273.900000    3          6.4    1.679181  Big-Screen-lover
# 1    A14219   3642.441950    2          4.0    2.682023      Sleeping-dog
# 2    A15312   3653.884565    2          5.0    3.208202      Sleeping-dog
# 3    A16605   3713.211107    2          6.6    0.900000        Early-bird
# 4    B10634   3391.074215    2          4.2    2.453656      Sleeping-dog
# 5    B16849   3755.263391    2          4.7    2.786665      Sleeping-dog
# 6    B18816   3213.911446    2          6.4    0.900000        Early-bird
# 7    C10639   3516.500000    2          5.2    2.564830  Big-Screen-lover
# 8    C12717   3732.900000    2          5.7    2.069995  Big-Screen-lover
# 9    C15050   4020.173425    2          4.9    3.013440      Sleeping-dog
# 10   C18306   4005.005142    2          4.7    3.113618      Sleeping-dog
# 11   C18622   3246.000000    1          5.0    1.891624  Big-Screen-lover
# ...

# %% [markdown]
# # 그룹핑을 하여 데이터 묶어보기 (주의! 그룹핑 후에는 항상 리셋을 해주어야 한다)

# %%
groupData = customerData2.groupby("EMI").max()
groupData
# Out:
#      CUSTID  AVERAGEPRICE  DEVICECOUNT  PRODUCTAGE      CUSTTYPE  \
# EMI
# 1    Y12458   3419.462596          6.3    2.994395  Sleeping-dog
# 2    Z19835   4166.533130          6.9    3.483573  Sleeping-dog
# 3    Z13534   4296.873743          6.9    2.055707    Early-bird
#
#      PRODUCTAGE_NEW  PRODUCTAGE_NEW2
# EMI
# 1                 3                5
# 2                 5                5
# 3                 3                5

# %%
groupData = groupData.reset_index()
groupData
# Out:
#    index          CUSTTYPE  CUSTID  AVERAGEPRICE  EMI  DEVICECOUNT  \
# 0      0  Big-Screen-lover  Z16735   4273.900000    3          6.9
# 1      1        Early-bird  Z19835   4296.873743    3          6.9
# 2      2      Sleeping-dog  Y12458   4166.533130    2          5.1
#
#    PRODUCTAGE  PRODUCTAGE_NEW  PRODUCTAGE_NEW2
# 0    3.367229               5                5
# 1    1.300000               2                2
# 2    3.483573               5                5

# %% [markdown]
# # 데이터의 컬럼을 추출하여 정렬 한 뒤 해당 컬럼의 평균과 표준편차 구하기

# %%
customerData3 = pd.read_csv("../dataset/kopo_channel_seasonality_new.csv")
customerData3.head()
# Out:
#   REGIONID    PRODUCT  YEARWEEK      QTY
# 0      A60   PRODUCT4    201402     71.0
# 1      A60  PRODUCT59    201402  22275.0
# 2      A60  PRODUCT34    201402   4463.0
# 3      A60  PRODUCT47    201402      0.0
# 4      A60  PRODUCT56    201402     23.0

# %%
sortkey2 = ["REGIONID","PRODUCT"]
customerData3.sort_values(sortkey2, inplace = True)

# %%
groupData2 = customerData3.groupby(["REGIONID","PRODUCT"]).agg(["mean","std"])["QTY"]
groupData2 = groupData2.reset_index()

# %%
customerData4 = pd.read_csv("../dataset/kopo_channel_seasonality_new.csv")
customerData4.head()
# Out:
#   REGIONID    PRODUCT  YEARWEEK      QTY
# 0      A60   PRODUCT4    201402     71.0
# 1      A60  PRODUCT59    201402  22275.0
# 2      A60  PRODUCT34    201402   4463.0
# 3      A60  PRODUCT47    201402      0.0
# 4      A60  PRODUCT56    201402     23.0

# %%
sortkey3 = ["REGIONID","PRODUCT","YEARWEEK"]
sortedData3 = customerData4.sort_values(sortkey3, inplace = False)

# %%
sortedData3.head()
# Out:
#      REGIONID    PRODUCT  YEARWEEK    QTY
# 298       A00  PRODUCT34    201401  661.0
# 1757      A00  PRODUCT34    201402  679.0
# 3125      A00  PRODUCT34    201403  578.0
# 205       A00  PRODUCT34    201404  532.0
# 4369      A00  PRODUCT34    201405  516.0

# %%
sortedData3["QTY_NEW"] = np.where(sortedData3["QTY"]<0,0,sortedData3["QTY"])

# %%
sortedData3["YEARWEEK"] = sortedData3.YEARWEEK.astype("str")

sortedData3["YEAR"] = sortedData3.YEARWEEK.str[0:4]
sortedData3["WEEK"] = sortedData3.YEARWEEK.str[4:]

# %%
sortedData3.head()
# Out:
#      REGIONID    PRODUCT YEARWEEK    QTY  QTY_NEW  YEAR WEEK
# 298       A00  PRODUCT34   201401  661.0    661.0  2014   01
# 1757      A00  PRODUCT34   201402  679.0    679.0  2014   02
# 3125      A00  PRODUCT34   201403  578.0    578.0  2014   03
# 205       A00  PRODUCT34   201404  532.0    532.0  2014   04
# 4369      A00  PRODUCT34   201405  516.0    516.0  2014   05

# %%
groupData3 = sortedData3.groupby(["REGIONID","PRODUCT","YEAR"]).agg(["mean","std"])["QTY_NEW"]
groupData3.head()
# Out:
#                                mean         std
# REGIONID PRODUCT   YEAR
# A00      PRODUCT34 2014  275.961538  162.179634
#                    2015   85.698113   72.858024
#                    2016   36.576923   94.897539
#          PRODUCT58 2014    2.673077    3.889257
#                    2015    7.547170   14.909427

# %%
groupData3 = groupData3.reset_index()

# %%
groupData3.columns = ["REGIONID", "PRODUCT", "YEAR", "QTY_MEAN", "QTY_STD"]

# %%
groupData3.head()
# Out:
#   REGIONID    PRODUCT  YEAR    QTY_MEAN     QTY_STD
# 0      A00  PRODUCT34  2014  275.961538  162.179634
# 1      A00  PRODUCT34  2015   85.698113   72.858024
# 2      A00  PRODUCT34  2016   36.576923   94.897539
# 3      A00  PRODUCT58  2014    2.673077    3.889257
# 4      A00  PRODUCT58  2015    7.547170   14.909427

# %%
customerData5 = pd.read_csv("../../01.Python_Git/dataset/customerdata.csv")
customerData5["TEST"] = customerData5["PRODUCTAGE"].rolling(window = 4, center = False).mean()
customerData5
# Out:
#      CUSTID  AVERAGEPRICE  EMI  DEVICECOUNT  PRODUCTAGE          CUSTTYPE  \
# 0    A13566   4273.900000    3          6.4    1.679181  Big-Screen-lover
# 1    A14219   3642.441950    2          4.0    2.682023      Sleeping-dog
# 2    A15312   3653.884565    2          5.0    3.208202      Sleeping-dog
# 3    A16605   3713.211107    2          6.6    0.900000        Early-bird
# 4    B10634   3391.074215    2          4.2    2.453656      Sleeping-dog
# 5    B16849   3755.263391    2          4.7    2.786665      Sleeping-dog
# 6    B18816   3213.911446    2          6.4    0.900000        Early-bird
# 7    C10639   3516.500000    2          5.2    2.564830  Big-Screen-lover
# 8    C12717   3732.900000    2          5.7    2.069995  Big-Screen-lover
# 9    C15050   4020.173425    2          4.9    3.013440      Sleeping-dog
# 10   C18306   4005.005142    2          4.7    3.113618      Sleeping-dog
# 11   C18622   3246.000000    1          5.0    1.891624  Big-Screen-lover
# ...

# %%
selloutData = pd.read_csv("../dataset/kopo_channel_seasonality_new.csv")
selloutData.head()
# Out:
#   REGIONID    PRODUCT  YEARWEEK      QTY
# 0      A60   PRODUCT4    201402     71.0
# 1      A60  PRODUCT59    201402  22275.0
# 2      A60  PRODUCT34    201402   4463.0
# 3      A60  PRODUCT47    201402      0.0
# 4      A60  PRODUCT56    201402     23.0

# %%
import numpy as np                   # 바꿀값    바꾼값    아니라면 놔둘 값
selloutData["QTY_NEW"] = np.where(selloutData["QTY"]<0,0,selloutData["QTY"])

# %%
# 0보다 작은 값의 QTY를 조회하여 확인하기
selloutData[selloutData["QTY"]<0].head()
# Out:
#      REGIONID    PRODUCT  YEARWEEK   QTY  QTY_NEW
# 65        A02  PRODUCT16    201403  -1.0      0.0
# 338       A08  PRODUCT36    201402  -1.0      0.0
# 1270      A14  PRODUCT36    201405  -1.0      0.0
# 1616      A17  PRODUCT60    201402  -1.0      0.0
# 2035      A39   PRODUCT7    201404 -12.0      0.0

# %%
selloutData["YEARWEEK"] = selloutData.YEARWEEK.astype("str")

selloutData["YEAR"] = selloutData.YEARWEEK.str[0:4]
selloutData["WEEK"] = selloutData.YEARWEEK.str[4:]
selloutData.head()
# Out:
#   REGIONID    PRODUCT YEARWEEK      QTY  QTY_NEW  YEAR WEEK
# 0      A60   PRODUCT4   201402     71.0     71.0  2014   02
# 1      A60  PRODUCT59   201402  22275.0  22275.0  2014   02
# 2      A60  PRODUCT34   201402   4463.0   4463.0  2014   02
# 3      A60  PRODUCT47   201402      0.0      0.0  2014   02
# 4      A60  PRODUCT56   201402     23.0     23.0  2014   02

# %%
refinedSelloutData = selloutData[selloutData.WEEK.astype(int) <= 52]

# %%
refinedSelloutData.head()
# Out:
#   REGIONID    PRODUCT YEARWEEK      QTY  QTY_NEW  YEAR WEEK
# 0      A60   PRODUCT4   201402     71.0     71.0  2014   02
# 1      A60  PRODUCT59   201402  22275.0  22275.0  2014   02
# 2      A60  PRODUCT34   201402   4463.0   4463.0  2014   02
# 3      A60  PRODUCT47   201402      0.0      0.0  2014   02
# 4      A60  PRODUCT56   201402     23.0     23.0  2014   02

# %%
regionMasterData = pd.read_csv("../dataset/kopo_region_mst.csv")
regionMasterData.head()
# Out:
#   REGIONID REGIONNAME
# 0      A00     AFRICA
# 1      A01    AMERICA
# 2      A02      KOREA
# 3      A03     GERMAN
# 4      A04     BRAZIL

# %%
selectExample = pd.read_csv("../dataset/kopo_channel_seasonality_new.csv")
selectExample.head()
# Out:
#   REGIONID    PRODUCT  YEARWEEK      QTY
# 0      A60   PRODUCT4    201402     71.0
# 1      A60  PRODUCT59    201402  22275.0
# 2      A60  PRODUCT34    201402   4463.0
# 3      A60  PRODUCT47    201402      0.0
# 4      A60  PRODUCT56    201402     23.0

# %%
mergeResult = pd.merge(selectExample,regionMasterData, left_on="REGIONID", right_on = "REGIONID")\
[["REGIONID","REGIONNAME","PRODUCT","YEARWEEK","QTY"]]

mergeResult.head()
# Out:
#   REGIONID REGIONNAME    PRODUCT  YEARWEEK      QTY
# 0      A60       THAI   PRODUCT4    201402     71.0
# 1      A60       THAI  PRODUCT59    201402  22275.0
# 2      A60       THAI  PRODUCT34    201402   4463.0
# 3      A60       THAI  PRODUCT47    201402      0.0
# 4      A60       THAI  PRODUCT56    201402     23.0

# %%
mergeKey = ["REGIONID","PRODUCT","YEAR"]
mergedData = pd.merge(refinedSelloutData,groupData3, left_on=mergeKey, right_on = mergeKey, how = "inner")\
[["REGIONID", "PRODUCT", "YEARWEEK","QTY_NEW","YEAR","WEEK","QTY_MEAN","QTY_STD"]]
mergedData
# Out:
#        REGIONID    PRODUCT YEARWEEK  QTY_NEW  YEAR WEEK   QTY_MEAN    QTY_STD
# 0           A60   PRODUCT4   201402     71.0  2014   02  29.134615  13.225093
# 1           A60   PRODUCT4   201401     16.0  2014   01  29.134615  13.225093
# 2           A60   PRODUCT4   201403     51.0  2014   03  29.134615  13.225093
# 3           A60   PRODUCT4   201406     19.0  2014   06  29.134615  13.225093
# 4           A60   PRODUCT4   201404     21.0  2014   04  29.134615  13.225093
# 5           A60   PRODUCT4   201405     18.0  2014   05  29.134615  13.225093
# 6           A60   PRODUCT4   201407     19.0  2014   07  29.134615  13.225093
# 7           A60   PRODUCT4   201409     18.0  2014   09  29.134615  13.225093
# 8           A60   PRODUCT4   201408     16.0  2014   08  29.134615  13.225093
# 9           A60   PRODUCT4   201411      5.0  2014   11  29.134615  13.225093
# 10          A60   PRODUCT4   201410     12.0  2014   10  29.134615  13.225093
# ...

# %%
sortkey4 = ["REGIONID","PRODUCT","YEARWEEK"]
mergedData = mergedData.sort_values(sortkey4, inplace = False)
mergedData
# Out:
#       REGIONID    PRODUCT YEARWEEK  QTY_NEW  YEAR WEEK     QTY_MEAN  \
# 10661      A00  PRODUCT34   201401    661.0  2014   01   275.961538
# 10662      A00  PRODUCT34   201402    679.0  2014   02   275.961538
# 10663      A00  PRODUCT34   201403    578.0  2014   03   275.961538
# 10660      A00  PRODUCT34   201404    532.0  2014   04   275.961538
# 10665      A00  PRODUCT34   201405    516.0  2014   05   275.961538
# 10664      A00  PRODUCT34   201406    423.0  2014   06   275.961538
# 10667      A00  PRODUCT34   201407    407.0  2014   07   275.961538
# 10668      A00  PRODUCT34   201408    364.0  2014   08   275.961538
# 10666      A00  PRODUCT34   201409    470.0  2014   09   275.961538
# 10669      A00  PRODUCT34   201410    538.0  2014   10   275.961538
# 10671      A00  PRODUCT34   201411    369.0  2014   11   275.961538
# 10670      A00  PRODUCT34   201412    352.0  2014   12   275.961538
# 10672      A00  PRODUCT34   201413    354.0  2014   13   275.961538
# ...

# %%
mergedData.reset_index(drop=True)
# Out:
#        REGIONID    PRODUCT YEARWEEK  QTY_NEW  YEAR WEEK     QTY_MEAN  \
# 0           A00  PRODUCT34   201401    661.0  2014   01   275.961538
# 1           A00  PRODUCT34   201402    679.0  2014   02   275.961538
# 2           A00  PRODUCT34   201403    578.0  2014   03   275.961538
# 3           A00  PRODUCT34   201404    532.0  2014   04   275.961538
# 4           A00  PRODUCT34   201405    516.0  2014   05   275.961538
# 5           A00  PRODUCT34   201406    423.0  2014   06   275.961538
# 6           A00  PRODUCT34   201407    407.0  2014   07   275.961538
# 7           A00  PRODUCT34   201408    364.0  2014   08   275.961538
# 8           A00  PRODUCT34   201409    470.0  2014   09   275.961538
# 9           A00  PRODUCT34   201410    538.0  2014   10   275.961538
# 10          A00  PRODUCT34   201411    369.0  2014   11   275.961538
# 11          A00  PRODUCT34   201412    352.0  2014   12   275.961538
# 12          A00  PRODUCT34   201413    354.0  2014   13   275.961538
# ...

# %%
import pandas as pd
import numpy as np

# %%
selloutData = pd.read_csv("../dataset/kopo_channel_seasonality_new.csv")
selloutData.head(1)
# Out:
#   REGIONID   PRODUCT  YEARWEEK   QTY
# 0      A60  PRODUCT4    201402  71.0

# %%
selloutData["NEW_QTY"] = np.where(selloutData["QTY"]< 0, 0, selloutData["QTY"])

# %%
selloutData[selloutData.QTY >= 0].head()
# Out:
#   REGIONID    PRODUCT  YEARWEEK      QTY  NEW_QTY
# 0      A60   PRODUCT4    201402     71.0     71.0
# 1      A60  PRODUCT59    201402  22275.0  22275.0
# 2      A60  PRODUCT34    201402   4463.0   4463.0
# 3      A60  PRODUCT47    201402      0.0      0.0
# 4      A60  PRODUCT56    201402     23.0     23.0

# %% [markdown]
# ### 53주차 제거

# %%
selloutData.dtypes
# Out:
# REGIONID     object
# PRODUCT      object
# YEARWEEK      int64
# QTY         float64
# NEW_QTY     float64
# dtype: object

# %%
## 연산과 자료형을 활용하여 데이터를 정제하기

# %%
def customFunction(inputColumn):
    yearValue = inputColumn / 100
    yearValue = int(yearValue)
    return yearValue

# %%
# 데이터를 정제하는 방법 활용 함수화, 연산, 자료형

# %%
# 방법 1 (자료형 변환)

# %%
selloutData["YEAR"] = (selloutData.YEARWEEK/100).astype(int)

# %%
# 방법 2 (함수 활용)

# %%
selloutData["YEAR"] = selloutData["YEARWEEK"].apply(customFunction)

# %%
# 방법 3 (연산자 활용)

# %%
selloutData["YEAR"] = selloutData["YEARWEEK"]//100

# %%
selloutData["WEEK"] = selloutData["YEARWEEK"]%100

# %%
refinedData = selloutData[selloutData.WEEK%100 < 53]

# %%
refinedData.head()
# Out:
#   REGIONID    PRODUCT  YEARWEEK      QTY  NEW_QTY  WEEK  YEAR
# 0      A60   PRODUCT4    201402     71.0     71.0     2  2014
# 1      A60  PRODUCT59    201402  22275.0  22275.0     2  2014
# 2      A60  PRODUCT34    201402   4463.0   4463.0     2  2014
# 3      A60  PRODUCT47    201402      0.0      0.0     2  2014
# 4      A60  PRODUCT56    201402     23.0     23.0     2  2014

# %%
sortkey = ['REGIONID', 'PRODUCT', 'YEARWEEK']

# %%
sortedData = refinedData.sort_values(sortkey)

# %%
sortedData.head()
# Out:
#      REGIONID    PRODUCT  YEARWEEK    QTY  NEW_QTY  WEEK  YEAR
# 298       A00  PRODUCT34    201401  661.0    661.0     1  2014
# 1757      A00  PRODUCT34    201402  679.0    679.0     2  2014
# 3125      A00  PRODUCT34    201403  578.0    578.0     3  2014
# 205       A00  PRODUCT34    201404  532.0    532.0     4  2014
# 4369      A00  PRODUCT34    201405  516.0    516.0     5  2014

# %%
### 기존 인덱스를 제거하고 새로운 인덱스(정렬된)를 적용

# %%
step1Data = sortedData.reset_index(drop = True)

# %%
step1Data.head()
# Out:
#   REGIONID    PRODUCT  YEARWEEK    QTY  NEW_QTY  WEEK  YEAR
# 0      A00  PRODUCT34    201401  661.0    661.0     1  2014
# 1      A00  PRODUCT34    201402  679.0    679.0     2  2014
# 2      A00  PRODUCT34    201403  578.0    578.0     3  2014
# 3      A00  PRODUCT34    201404  532.0    532.0     4  2014
# 4      A00  PRODUCT34    201405  516.0    516.0     5  2014

# %%
### 롤링함수를 적용가기전에는 정렬을 해줘야한다.

# %%
### 1. 기본 이동평균 함수

# %%
step1Data["MA"] = step1Data.NEW_QTY.rolling(window = 15, center=True, min_periods=1).mean()

# %%
step1Data.head()
# Out:
#   REGIONID    PRODUCT  YEARWEEK    QTY  NEW_QTY  WEEK  YEAR          MA
# 0      A00  PRODUCT34    201401  661.0    661.0     1  2014  520.000000
# 1      A00  PRODUCT34    201402  679.0    679.0     2  2014  514.444444
# 2      A00  PRODUCT34    201403  578.0    578.0     3  2014  516.800000
# 3      A00  PRODUCT34    201404  532.0    532.0     4  2014  503.363636
# 4      A00  PRODUCT34    201405  516.0    516.0     5  2014  490.750000
